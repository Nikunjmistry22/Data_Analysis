# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikunjmistry22/Weather_Data_Analysis/blob/main/Weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-aea2aaf8-2bd0-48ff-958f-26e4f77f593b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aea2aaf8-2bd0-48ff-958f-26e4f77f593b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1. Weather Data.csv to 1. Weather Data.csv

# %%
data=pd.read_csv('1. Weather Data.csv')
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data.count
# Out:
# <bound method DataFrame.count of              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_% Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86           float
# 1        1/1/2012 1:00    -1.8              -3.7         87           float
# 2        1/1/2012 2:00    -1.8              -3.4         89           float
# 3        1/1/2012 3:00    -1.5              -3.2         88           float
# 4        1/1/2012 4:00    -1.5              -3.3         88           float
# ...                ...     ...               ...        ...             ...
# 8779  12/31/2012 19:00     0.1              -2.7         81           float
# 8780  12/31/2012 20:00     0.2              -2.4         83           float
# 8781  12/31/2012 21:00    -0.5              -1.5         93           float
# 8782  12/31/2012 22:00    -0.2              -1.8         89           float
# 8783  12/31/2012 23:00     0.0              -2.1         86           float
#
# ...

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h        1
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   object
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 549.1+ KB

# %%
data.head(2)
data[data.Weather == 'Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_% Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50           float
# 114     1/5/2012 18:00    -7.1             -14.4         56           float
# 115     1/5/2012 19:00    -9.2             -15.4         61           float
# 116     1/5/2012 20:00    -9.8             -15.7         62           float
# 117     1/5/2012 21:00    -9.0             -14.8         63           float
# ...                ...     ...               ...        ...             ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89           float
# 8698  12/28/2012 10:00    -6.1              -8.6         82           float
# 8713   12/29/2012 1:00   -11.9             -13.6         87           float
# 8714   12/29/2012 2:00   -11.8             -13.1         90           float
# 8756  12/30/2012 20:00   -13.8             -16.5         80           float
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
data.head(3)
data.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_% Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50           float
# 114     1/5/2012 18:00    -7.1             -14.4         56           float
# 115     1/5/2012 19:00    -9.2             -15.4         61           float
# 116     1/5/2012 20:00    -9.8             -15.7         62           float
# 117     1/5/2012 21:00    -9.0             -14.8         63           float
# ...                ...     ...               ...        ...             ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89           float
# 8698  12/28/2012 10:00    -6.1              -8.6         82           float
# 8713   12/29/2012 1:00   -11.9             -13.6         87           float
# 8714   12/29/2012 2:00   -11.8             -13.1         90           float
# 8756  12/30/2012 20:00   -13.8             -16.5         80           float
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
data.head(3)
data[(data['Weather'] == 'Fog') & (data['Temp_C'] > -1)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_% Wind Speed_km/h  \
# 11      1/1/2012 11:00    -0.5              -2.1         89           float
# 12      1/1/2012 12:00    -0.2              -2.0         88           float
# 13      1/1/2012 13:00     0.2              -1.7         87           float
# 14      1/1/2012 14:00     0.8              -1.1         87           float
# 15      1/1/2012 15:00     1.8              -0.4         85           float
# ...                ...     ...               ...        ...             ...
# 8085   12/2/2012 21:00     6.7               6.6         99           float
# 8215    12/8/2012 7:00     2.3               1.0         91           float
# 8230   12/8/2012 22:00     1.2               0.6         96           float
# 8232    12/9/2012 0:00     1.5               0.7         94           float
# 8483  12/19/2012 11:00     0.8               0.2         96           float
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(data['Temp_C'])
plt.show()

# %%
plt.hist(data['Visibility_km'],bins=10,facecolor="red")
plt.show()

# %%
plt.stem(data['Rel Hum_%'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.

# %%
data.to_html('Weather-Report')
pd.read_html('Weather-Report')
# Out:
# [      Unnamed: 0         Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
#  0              0     1/1/2012 0:00    -1.8              -3.9         86
#  1              1     1/1/2012 1:00    -1.8              -3.7         87
#  2              2     1/1/2012 2:00    -1.8              -3.4         89
#  3              3     1/1/2012 3:00    -1.5              -3.2         88
#  4              4     1/1/2012 4:00    -1.5              -3.3         88
#  ...          ...               ...     ...               ...        ...
#  8779        8779  12/31/2012 19:00     0.1              -2.7         81
#  8780        8780  12/31/2012 20:00     0.2              -2.4         83
#  8781        8781  12/31/2012 21:00    -0.5              -1.5         93
#  8782        8782  12/31/2012 22:00    -0.2              -1.8         89
#  8783        8783  12/31/2012 23:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# ...
